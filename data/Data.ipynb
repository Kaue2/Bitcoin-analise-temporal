# %% [markdown]
# O código a seguir é um script simples de onde estamos tirando nossos dados. O Yahoo Finance possui uma API muito acessível de ser utilizada, de onde estamos extraindo todos os dados.

# %%
import yfinance as yf
btc = yf.download("BTC-USD", period="max")
print(btc.head)
# Out:
# C:\Users\kaueo\AppData\Local\Temp\ipykernel_7072\152202547.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   btc = yf.download("BTC-USD", period="max")
# [*********************100%***********************]  1 of 1 completed
# <bound method NDFrame.head of Price              Close          High           Low          Open  \
# Ticker           BTC-USD       BTC-USD       BTC-USD       BTC-USD
# Date
# 2014-09-17    457.334015    468.174011    452.421997    465.864014
# 2014-09-18    424.440002    456.859985    413.104004    456.859985
# 2014-09-19    394.795990    427.834991    384.532013    424.102997
# 2014-09-20    408.903992    423.295990    389.882996    394.673004
# 2014-09-21    398.821014    412.425995    393.181000    408.084991
# ...                  ...           ...           ...           ...
# 2025-11-24  88270.562500  89206.335938  85272.195312  86798.773438
# 2025-11-25  87341.890625  88457.335938  86131.429688  88269.960938
# ...
